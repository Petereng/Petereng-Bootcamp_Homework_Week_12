# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# %matplotlib inline

from newsapi.newsapi_client import NewsApiClient
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\peter\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
# YOUR CODE HERE!

load_dotenv()

# Set News API Key

api_key = os.getenv("NEWS_API_KEY")

newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# %%
# Create a newsapi client
# YOUR CODE HERE!

newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!

btc_headlines = newsapi.get_everything(
    q="bitcoin AND BTC",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!

eth_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# NOTE TO SELF -> using ETH in the search erroneously brought back Ethan Allen Interiors NYSE:ETH

# {'source': {'id': None, 'name': 'MarketBeat'},
#  'author': 'Thomas Hughes',
#  'title': 'Building A Quality Portfolio With Ethan Allen Interiors',
#  'description': "It's no secret that we are fond of the furniture industry and Ethan Allen Interiors (NYSE: ETH) is part of this big picture. The company is a mostly N...",
#  'url': 'https://www.marketbeat.com/originals/building-a-quality-portfolio-with-ethan-allen-interiors/?utm_source=entrepreneurcom&amp;amp;utm_medium=entrepreneurcom',
#  'urlToImage': 'https://assets.entrepreneur.com/providers/marketbeat/hero-image-marketbeat-379835.jpeg',
#  'publishedAt': '2021-08-10T12:10:00Z',
#  'content': "August\r\n10, 2021\r\n4 min read\r\nThis story originally appeared on MarketBeatEthan Allen Interiors Is A Must-Buy For Dividend Growth Investors\r\nIt's no secret that we are fond of the furniture industry … [+4048 chars]"}

# %%
btc_headlines["articles"][0]
# Out:
# {'source': {'id': None, 'name': 'BeInCrypto'},
#  'author': 'Nicholas Pongratz',
#  'title': 'Bitcoin Mutual Fund Hits the Market as Crypto ETP Race Heats Up',
#  'description': 'Maryland-based ProFunds is launching a publicly available mutual fund connected to the value of bitcoin (BTC).',
#  'url': 'https://beincrypto.com/bitcoin-mutual-fund-hits-the-market-as-crypto-etp-race-heats-up/',
#  'urlToImage': 'https://assets.entrepreneur.com/providers/be-in-crypto/hero-image-be-in-crypto-378754.jpeg',
#  'publishedAt': '2021-07-29T11:45:36Z',
#  'content': 'This story originally appeared on be[IN]cryptoMaryland-based ProFunds is launching a publicly available mutual fund connected to the value of bitcoin (BTC).\r\nThe Bitcoin Strategy ProFund invests in b… [+1875 chars]'}

# %%
eth_headlines["articles"][0]
# Out:
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Lucas Matney',
#  'title': 'Tenderly raises $15.3M to help Ethereum developers ship decentralized apps faster',
#  'description': 'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto space in 2021. The latest crypto startup to court the attenti…',
#  'url': 'http://techcrunch.com/2021/07/29/tenderly-raises-15-3m-to-help-ethereum-developers-ship-decentralized-apps-faster/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/07/Tenderly-Founding-Team-1.jpg?w=600',
#  'publishedAt': '2021-07-29T18:27:16Z',
#  'content': 'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame

# YOUR CODE HERE!

btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass

# %%
# Create BTC DataFrame

btc_df = pd.DataFrame(btc_sentiments)

btc_df
# Out:
#                                                  text        date  compound  \
# 0   This story originally appeared on be[IN]crypto...  2021-07-29    0.3400
# 1   August\r\n6, 2021\r\n3 min read\r\nThis articl...  2021-08-06   -0.3400
# 2   August\r\n21, 2021\r\n2 min read\r\nThis story...  2021-08-21    0.2960
# 3   Bitcoin has climbed sharply in recent days.\r\...  2021-07-29    0.3400
# 4   August\r\n18, 2021\r\n3 min read\r\nOpinions e...  2021-08-18   -0.3818
# ..                                                ...         ...       ...
# 95  Shares of Altria Group Inc. gained 0.5% in pre...  2021-07-29    0.7717
# 96  Today publicly traded HIVE Blockchain announce...  2021-08-13    0.0000
# 97  BeInCrypto \r\nMultibillion-dollar asset manag...  2021-08-21    0.4939
# 98  CleanSpark, a software and services company th...  2021-08-03    0.5423
# 99  peshkov/iStock via Getty Images\r\nInvestor ps...  2021-08-15    0.8176
#
#     positive  negative  neutral
# 0      0.079     0.000    0.921
# 1      0.000     0.066    0.934
# 2      0.066     0.000    0.934
# 3      0.066     0.000    0.934
# 4      0.000     0.077    0.923
# ..       ...       ...      ...
# 95     0.216     0.000    0.784
# 96     0.000     0.000    1.000
# 97     0.130     0.000    0.870
# 98     0.130     0.000    0.870
# 99     0.227     0.000    0.773
#
# [100 rows x 6 columns]

# %%
# Reorder BTC DataFrame columns

cols = ["date", "text", "compound", "positive", "negative", "neutral"]

btc_df = btc_df[cols]

btc_df
# Out:
#           date                                               text  compound  \
# 0   2021-07-29  This story originally appeared on be[IN]crypto...    0.3400
# 1   2021-08-06  August\r\n6, 2021\r\n3 min read\r\nThis articl...   -0.3400
# 2   2021-08-21  August\r\n21, 2021\r\n2 min read\r\nThis story...    0.2960
# 3   2021-07-29  Bitcoin has climbed sharply in recent days.\r\...    0.3400
# 4   2021-08-18  August\r\n18, 2021\r\n3 min read\r\nOpinions e...   -0.3818
# ..         ...                                                ...       ...
# 95  2021-07-29  Shares of Altria Group Inc. gained 0.5% in pre...    0.7717
# 96  2021-08-13  Today publicly traded HIVE Blockchain announce...    0.0000
# 97  2021-08-21  BeInCrypto \r\nMultibillion-dollar asset manag...    0.4939
# 98  2021-08-03  CleanSpark, a software and services company th...    0.5423
# 99  2021-08-15  peshkov/iStock via Getty Images\r\nInvestor ps...    0.8176
#
#     positive  negative  neutral
# 0      0.079     0.000    0.921
# 1      0.000     0.066    0.934
# 2      0.066     0.000    0.934
# 3      0.066     0.000    0.934
# 4      0.000     0.077    0.923
# ..       ...       ...      ...
# 95     0.216     0.000    0.784
# 96     0.000     0.000    1.000
# 97     0.130     0.000    0.870
# 98     0.130     0.000    0.870
# 99     0.227     0.000    0.773
#
# [100 rows x 6 columns]

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!

eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass

# %%
# Create ETH DataFrame

eth_df = pd.DataFrame(eth_sentiments)

eth_df
# Out:
#                                                  text        date  compound  \
# 0   Blockchain infrastructure startups are heating...  2021-07-29   -0.2411
# 1   Cent was founded in 2017 as an ad-free creator...  2021-08-05    0.6956
# 2   After the bell today, Coinbase reported anothe...  2021-08-10    0.5719
# 3   Representation of the Ethereum virtual currenc...  2021-08-05    0.0000
# 4   HONG KONG, Aug 5 (Reuters) - Ether held near t...  2021-08-05    0.0000
# ..                                                ...         ...       ...
# 95  Poly Network, the cryptocurrency interoperabil...  2021-08-11   -0.7096
# 96  Nvidia CEO Jensen Huang\r\nMandel Ngan/AFP via...  2021-08-19    0.2960
# 97  People walk past the New York Stock Exchange (...  2021-08-10    0.4588
# 98  Welcome to 10 Things Before the Opening Bell. ...  2021-07-23    0.4588
# 99  Name: Alex Masmej\r\nAge: 24\r\nLocation: San ...  2021-08-10    0.0000
#
#     positive  negative  neutral
# 0      0.000     0.061    0.939
# 1      0.190     0.000    0.810
# 2      0.139     0.000    0.861
# 3      0.000     0.000    1.000
# 4      0.000     0.000    1.000
# ..       ...       ...      ...
# 95     0.000     0.174    0.826
# 96     0.066     0.000    0.934
# 97     0.077     0.000    0.923
# 98     0.079     0.000    0.921
# 99     0.000     0.000    1.000
#
# [100 rows x 6 columns]

# %%
# Reorder BTC DataFrame columns

cols = ["date", "text", "compound", "positive", "negative", "neutral"]

eth_df = eth_df[cols]

eth_df
# Out:
#           date                                               text  compound  \
# 0   2021-07-29  Blockchain infrastructure startups are heating...   -0.2411
# 1   2021-08-05  Cent was founded in 2017 as an ad-free creator...    0.6956
# 2   2021-08-10  After the bell today, Coinbase reported anothe...    0.5719
# 3   2021-08-05  Representation of the Ethereum virtual currenc...    0.0000
# 4   2021-08-05  HONG KONG, Aug 5 (Reuters) - Ether held near t...    0.0000
# ..         ...                                                ...       ...
# 95  2021-08-11  Poly Network, the cryptocurrency interoperabil...   -0.7096
# 96  2021-08-19  Nvidia CEO Jensen Huang\r\nMandel Ngan/AFP via...    0.2960
# 97  2021-08-10  People walk past the New York Stock Exchange (...    0.4588
# 98  2021-07-23  Welcome to 10 Things Before the Opening Bell. ...    0.4588
# 99  2021-08-10  Name: Alex Masmej\r\nAge: 24\r\nLocation: San ...    0.0000
#
#     positive  negative  neutral
# 0      0.000     0.061    0.939
# 1      0.190     0.000    0.810
# 2      0.139     0.000    0.861
# 3      0.000     0.000    1.000
# 4      0.000     0.000    1.000
# ..       ...       ...      ...
# 95     0.000     0.174    0.826
# 96     0.066     0.000    0.934
# 97     0.077     0.000    0.923
# 98     0.079     0.000    0.921
# 99     0.000     0.000    1.000
#
# [100 rows x 6 columns]

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!

btc_df.describe()
# Out:
#          compound   positive    negative     neutral
# count  100.000000  100.00000  100.000000  100.000000
# mean     0.222091    0.07800    0.019640    0.902320
# std      0.395775    0.08201    0.039103    0.083287
# min     -0.757900    0.00000    0.000000    0.631000
# 25%      0.000000    0.00000    0.000000    0.847750
# 50%      0.196200    0.06600    0.000000    0.913000
# 75%      0.561025    0.13000    0.000000    1.000000
# max      0.921700    0.36900    0.175000    1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!

eth_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.066651    0.047690    0.028400    0.923900
# std      0.362000    0.057615    0.048979    0.069196
# min     -0.757900    0.000000    0.000000    0.737000
# 25%     -0.051350    0.000000    0.000000    0.886750
# 50%      0.000000    0.038000    0.000000    0.929000
# 75%      0.323650    0.074000    0.054750    1.000000
# max      0.750600    0.201000    0.177000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin's mean positive score was higher versus ethereum's positive mean score
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin's max compound score higher versus ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin's max positive score was higest versus ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!

wnlemmatizer = WordNetLemmatizer()

# %%
# Create a list of stopwords
# YOUR CODE HERE!

# sw = set (stopwords.words ('english'))

# %%
# Expand the default stopwords list if necessary
# YOUR CODE HERE!

add_stopwords = [',', '', 'https', 'http', 'btc', 'bitcoin', 'eth', 'ethereum', 'char', 'u']
sw = set (stopwords.words('english') + add_stopwords)

# sw

# %%
# Complete the tokenizer function

# **************************************************************************************** CONFUSED, ASK KHALED FOR HELP **************************************************
# WEEK 12 / 1 / 04-Crude_stopwords/Solved/
# *************************************************************************************************************************************************************************


# def clean_text(article):
#     sw = set(stopwords.words('english'))
#     regex = re.compile("[^a-zA-Z ]")
    
#     re_clean = regex.sub('', article)
#     words = word_tokenize(re_clean)
#     output = [word.lower() for word in words if word.lower() not in sw]
#     return output

def tokenizer(text):
    
    """Tokenizes text."""
    
    # Remove the punctuation from text

   
    # Create a tokenized list of the words
    
    text = word_tokenize(text)
      
    regex = re.compile("[^a-zA-Z ]")
    text = [regex.sub('', word) for word in text]

    # Convert the words to lowercase
    
    text = [word.lower() for word in text]    
    
    # Remove the stop words
    
              
    # Lemmatize words into root words

#     list = []
#     for word in words:
#         if word not in sw:
#             list.append(word)
#     wnlemmatizer = WordNetLemmatizer()

    text = [word for word in text if word not in punctuation]
    text = [word for word in text if word not in sw]
    text = [wnlemmatizer.lemmatize(word) for word in text]
    return text
              
#     return tokens

# %%
# tokenizer("Hello pet3r, how are you doing, long walking time happining ain't see any-thing? !! '")

# %%
btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-07-29  This story originally appeared on be[IN]crypto...    0.3400
# 1  2021-08-06  August\r\n6, 2021\r\n3 min read\r\nThis articl...   -0.3400
# 2  2021-08-21  August\r\n21, 2021\r\n2 min read\r\nThis story...    0.2960
# 3  2021-07-29  Bitcoin has climbed sharply in recent days.\r\...    0.3400
# 4  2021-08-18  August\r\n18, 2021\r\n3 min read\r\nOpinions e...   -0.3818
#
#    positive  negative  neutral
# 0     0.079     0.000    0.921
# 1     0.000     0.066    0.934
# 2     0.066     0.000    0.934
# 3     0.066     0.000    0.934
# 4     0.000     0.077    0.923

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!

# *************************************************************************************************************************************************************************
# WEEK 12 / 1 / 08-Stu_Counter/Solved/
# *************************************************************************************************************************************************************************

btc_df['Tokens'] = btc_df["text"].apply(tokenizer)
btc_df.head()
# Out:
# C:\Users\peter\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          date                                               text  compound  \
# 0  2021-07-29  This story originally appeared on be[IN]crypto...    0.3400
# 1  2021-08-06  August\r\n6, 2021\r\n3 min read\r\nThis articl...   -0.3400
# 2  2021-08-21  August\r\n21, 2021\r\n2 min read\r\nThis story...    0.2960
# 3  2021-07-29  Bitcoin has climbed sharply in recent days.\r\...    0.3400
# 4  2021-08-18  August\r\n18, 2021\r\n3 min read\r\nOpinions e...   -0.3818
#
#    positive  negative  neutral  \
# 0     0.079     0.000    0.921
# 1     0.000     0.066    0.934
# 2     0.066     0.000    0.934
# 3     0.066     0.000    0.934
# 4     0.000     0.077    0.923
#
#                                               Tokens
# 0  [story, originally, appeared, cryptomarylandba...
# 1  [august, min, read, article, translated, spani...
# 2  [august, min, read, story, originally, appeare...
# 3  [climbed, sharply, recent, day, reutersdado, r...
# 4  [august, min, read, opinion, expressed, entrep...

# %%
# Create a new tokens column for Ethereum
eth_df['Tokens'] = eth_df["text"].apply(tokenizer)
eth_df.head()
# Out:
# C:\Users\peter\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          date                                               text  compound  \
# 0  2021-07-29  Blockchain infrastructure startups are heating...   -0.2411
# 1  2021-08-05  Cent was founded in 2017 as an ad-free creator...    0.6956
# 2  2021-08-10  After the bell today, Coinbase reported anothe...    0.5719
# 3  2021-08-05  Representation of the Ethereum virtual currenc...    0.0000
# 4  2021-08-05  HONG KONG, Aug 5 (Reuters) - Ether held near t...    0.0000
#
#    positive  negative  neutral  \
# 0     0.000     0.061    0.939
# 1     0.190     0.000    0.810
# 2     0.139     0.000    0.861
# 3     0.000     0.000    1.000
# 4     0.000     0.000    1.000
#
#                                               Tokens
# 0  [blockchain, infrastructure, startup, heating,...
# 1  [cent, founded, adfree, creator, network, allo...
# 2  [bell, today, coinbase, reported, another, per...
# 3  [representation, virtual, currency, standing, ...
# 4  [hong, kong, aug, reuters, ether, held, near, ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# ******************************************************************************** CONFUSED, ASK KHALED FOR HELP ***********************************************************
# WEEK 12 / 1 / 07-Ins_Ngram_Count/Solved/
# *************************************************************************THIS IS WHERE MY CRAPPY CODE SKILLS LET ME DOWN**************************************************

btc_token_list = [y for x in btc_df['Tokens'].to_list() for y in x ]
eth_token_list = [y for x in eth_df['Tokens'].to_list() for y in x ]

# %%
# Generate the Bitcoin N-grams where N=2

# YOUR CODE HERE!
btc_ngrams = ngrams(btc_token_list, 2)

# %%
# Print top 10 BTC bigrams
Counter(btc_ngrams).most_common(10)
# Out:
# [(('getty', 'image'), 7),
#  (('char', 'august'), 6),
#  (('story', 'originally'), 5),
#  (('originally', 'appeared'), 5),
#  (('august', 'min'), 5),
#  (('min', 'read'), 5),
#  (('via', 'getty'), 5),
#  (('char', 'beincrypto'), 5),
#  (('u', 'security'), 4),
#  (('security', 'exchange'), 4)]

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!

eth_ngrams = ngrams(eth_token_list, 2)

# %%
# Print top 10 ETH bigrams
Counter(eth_ngrams).most_common(10)
# Out:
# [(('aug', 'reuters'), 21),
#  (('illustration', 'taken'), 17),
#  (('char', 'representation'), 14),
#  (('taken', 'june'), 11),
#  (('york', 'aug'), 8),
#  (('representation', 'cryptocurrencies'), 8),
#  (('pc', 'motherboard'), 7),
#  (('new', 'york'), 7),
#  (('cryptocurrency', 'seen'), 7),
#  (('poly', 'network'), 7)]

# %%
# **************************************************************************************** CONFUSED, ASK KHALED FOR HELP **************************************************
# WEEK 12 / 1 / 08-Stu_Counter/Solved/
# *************************************************************************************************************************************************************************

def word_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
#     processed = process_text(big_string)
    top_10 = dict(Counter(corpus).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!

word_counter(btc_token_list)
# Out:
#              word  count
# 0            char    100
# 1  cryptocurrency     17
# 2           price     16
# 3          crypto     16
# 4          market     16
# 5             may     12
# 6        exchange     12
# 7            week     12
# 8         trading     12
# 9               u     11

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!

word_counter(eth_token_list)
# Out:
#              word  count
# 0            char    100
# 1         reuters     33
# 2  cryptocurrency     31
# 3             aug     22
# 4  representation     18
# 5    illustration     18
# 6           taken     17
# 7               u     17
# 8          dollar     16
# 9           stock     14

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
# ***********************************************************************************************
# WEEK 12 / 1 / 09-Ins_Word_Cloud/Solved/
# ***********************************************************************************************

from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!

# def process_text(doc):
cleaned_btc_text = " ".join(tokenizer(btc_df["text"].str.cat()))

# %%
# Process text for BTC wordcloud creation
btc_cloud = WordCloud().generate(cleaned_btc_text)

# %%
# Generate BTC wordcloud
plt.imshow(btc_cloud)

# %%
# Generate BTC word cloud with max_words parameter
btc_cloud = WordCloud(width=1200, height=800, max_words=50).generate(cleaned_btc_text)
plt.imshow(btc_cloud)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!

# def process_text(doc):
cleaned_eth_text = " ".join(tokenizer(eth_df["text"].str.cat()))

# %%
# Process text for ETH wordcloud creation
eth_cloud = WordCloud().generate(cleaned_eth_text)

# %%
# Generate ETH wordcloud
plt.imshow(eth_cloud)

# %%
# Generate ETH word cloud with max_words parameter

eth_cloud = WordCloud(width=1200, height=800, max_words=50).generate(cleaned_eth_text)
plt.imshow(eth_cloud)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
# !pip install spacy

# NOTE TO MARKER - Hi, i am getting an error: type object 'h5py.h5.H5PYConfig' has no attribute '__reduce_cython__'
# multiple attempts to reinstall and fix this has wasted around 3 hours of time

import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# nlp = spacy.load("en_core_web_sm")

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
### ***********************************************************************************************
# WEEK 12 / 3/ 04-Ins_NER/Solved/
# ***********************************************************************************************

# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!

ner_btc_text = " ".join(tokenizer(btc_df["text"].str.cat()))

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Set article to be analyzed with spaCy
btc_doc = nlp(ner_btc_text)

# %%
# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# Render NER visualization with displacy
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">story originally appeared cryptomarylandbased profunds launching publicly available mutual fund connected value strategy profund invests b char
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  min read article translated
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  edition using ai technology error may exist due process criptomonedas boom
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  char
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  min read story originally appeared cryptothe
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     u security exchange commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  concluded judgement
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  key individual tied defu char climbed sharply
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reutersdado ruvic facing doordie moment could move sharply higher hold stellar
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  gain taken char
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  min read opinion expressed entrepreneur contributor
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  world continuing battle pandemic unique thing started happen char
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  min read story originally appeared pennystocksbitcoin price surge helped boost penny stock thanks surge price dogecoin seve char article translated
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  edition using ai technology error may exist due process opinion expressed entrepreneur contributor much said char get roundup techcrunchs biggest important story delivered inbox every day pm pdt subscribe hello welcome extra crunch
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     july
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  go char
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     august
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  min read story originally appeared marketbeatthink might want invest cryptocurrency part portfolio long afford lose char im
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kevin guy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  bought
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yesterday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  really wanted keep quiet possible nt feel anymore side happened e char rally
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  wasnt helpwanted ad
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amazoncom inc crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  analyst saidthe ad seeking digital currency blockchain product lead got credit getting ball char story originally appeared valuewalkcryptocurrencies roller coaster ride year far price
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crashing month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reaching recordbreaking high past char hello welcome back weve thinking gary
# <mark class="entity" style="background: #7aece

# %%
# List all Entities
# YOUR CODE HERE!

print([ent.text for ent in btc_doc.ents if ent.label_])
# Out:
# ['august', 'spanish', 'last year', 'half', 'august', 'u security exchange commission', 'sec', 'three', 'recent day', 'weekly', 'august', 'earlier year', 'august', 'spanish', 'july', 'august', 'kevin guy', 'yesterday', 'monday', 'amazoncom inc crypto', 'crashing month', 'gensler', 'u security exchange commission', 'two', 'spanish', 'america', 'uk', 'joseph', 'spain', 'july', 'sunday', 'weekly', 'week', 'san francisco', 'english', 'french', 'monday', 'james jin cheng', 'july', 'monday', 'last hour', 'friday', 'u security exchange commission', 'sec', 'august', 'last week', 'senate', 'trillion', 'first', 'amazoncom inc', 'eight', 'past week', 'first', 'european', 'suisse swiss', 'today', 'multimonth', 'last week', 'analysis week', 'daily', 'six week', 'monday', 'el salvador', 'week', 'one', 'richard nixon', 'sunday', 'first', 'last month', 'u variation char stock exchange thailand', 'first', 'june', 'canada', 'satoshi portal inc', 'canada', 'satoshi portal inc', 'july', 'american', 'five', 'cnbc', 'tuesday', 'year', 'lo char amazoncom inc', 'monday', 'year', 'london', 'beincrypto week', 'july', 'third', 'kristyleigh minehan char beincrypto leading mortgage', 'u united whole mortgage', 'past week', 'tuesday', 'past week', 'time past hour', 'today', 'launching decade ago', 'two', 'second quarter fiscal year', 'one', 'resistan', 'el salvador something', 'amazoncom inc involvement', 'monthly', 'july', 'la vega aug', 'mara char beincrypto investment management', 'u security exchange commission', 'sec', 'char indian exchange', 'today', 'mellon', 'one', 'mar char hacker', 'million', 'first', 'zhao changpeng', 'binance bloomberg', 'daily', 'london', 'million', 'first', 'monday', 'morning', 'early monday', 'thursday', 'today', 'first', 'char cleanspark software', 'december']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

ner_eth_text = " ".join(tokenizer(eth_df["text"].str.cat()))

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

eth_doc = nlp(ner_eth_text)

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">blockchain infrastructure startup heating industry fervor brings developer user space still feel extremely young despite heavy institutional embrace
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crypto char cent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  founded adfree creator network allows user offer crypto reward good post comment like gifting award reddit char bell
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  coinbase reported another period impressive result second quarter earnings report
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  coinbase total revenue reached billion helped char representation virtual currency standing pc motherboard seen illustration picture
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     february
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reutersdado ruvicillustrationnew york aug
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  maj char
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hong kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  aug
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ether held near twomonth high
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ahead major adjustment underlying blockchain would alter way transaction processed char representation cryptocurrencies placed pc motherboard illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     june
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reutersdado ruvicillustrationaug
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  platform char cryptocurrencies spiked
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  amazon listed open job digital currency blockchain product lead amazon known plummeting stock wouldbe rival whenever rumor swirl char vitalik buterin founder techcrunch disrupt
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     london
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     john phillipsgetty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  image techcrunch cocreator vitalik buterin joined dogecoin foundation char maryann russonbusiness reporter
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bbc news hacker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  behind
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  largest ever cryptocurrency heist ever returned
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     almost half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  stolen asset
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yesterday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  blockchain char representation cryptocurrency placed pc motherboard illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     june
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reutersdado
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ruvicillustrationnew york
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     july
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  secondla char
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; ve

# %%
# List all Entities
# YOUR CODE HERE!

print([ent.text for ent in eth_doc.ents if ent.label_])
# Out:
# ['crypto char cent', 'today', 'quarter', 'february', 'reuters', 'hong kong', 'reuters', 'thursday', 'june', 'reuters', 'monday', 'london', 'john phillipsgetty', 'bbc news hacker', 'one', 'almost half', 'yesterday', 'june', 'ruvicillustrationnew york', 'july', 'reuters', 'million', 'august sunday', 'spanish', 'guadalajara', 'first', 'jack taylorgetty', 'u security exchange commission', 'wednesday', 'monday', 'chicago', 'la', 'buterin john phillips', 'thursday', 'jack', 'mark zuckerberg', 'american express', 'alesia haas', 'june', 'reuters', 'new york', 'fifth consecutive week', 'august', 'ruvicillustrationnew', 'reuters', 'late thursday', 'august', 'reuters', 'friday', 'june', 'suillustrationaug reuters', 'chinese', 'tuesday', 'last hour', 'last day', 'washington', 'reuters', 'tuesday', 'million', 'washington reuters', 'tuesday', 'million', 'reuters', 'june', 'february', 'reuters', 'tesla inc', 'tslao w', 'june', 'suillustrationfilesnew york', 'reuters', 'thursday', 'weekly', 'american', 'spanish', 'late december', 'one', 'dai', 'june', 'earlier week', 'last couple year', 'earlier week', 'mill char hacker', 'one', 'week', 'netw', 'london', 'reuters', 'japanese', 'thursday', 'million', 'american express', 'last month', 'billion', 'spanish', 'last week', 'withou char', 'brian armstrong', 'thursday', 'million', 'dozen', 'jack', 'june', 'july', 'new york', 'reuters', 'beirut', 'lebanon', 'azakirlondon aug', 'reuters', 'u dollar', 'friday', 'june', 'yorkbenga', 'seoul', 'south korea', 'june', 'june', 'new york', 'reuters', 'reuters', 'u dollar', 'august', 'sec', 'deutsche bank', 'thursday', 'one', 'august', 'today', 'stole hundred million', 'stole roughly million', 'today', 'tokyo', 'japan', 'new york', 'reuters', 'wednesday', 'u federal reserve', 'reuters', 'wednesday', 'yorklondon aug', 'reuters', 'thursday', 'morning', 'friday', 'one dollar', 'february', 'ruvicillustrationhong kong', 'reuters', 'asian', 'new york', 'reuters', 'thursday day', 'federal reserve', 'london', 'reuters', 'eightday', 'thursday', 'remark', 'u federal reserve', 'european', 'hong kong', 'asian', 'friday', 'first day', 'china', 'hangzhou', 'zhejiang', 'tokyo', 'reuters', 'friday', 'four month', 'londonhong kong', 'reuters', 'friday', 'weekly', 'european', 'thai', 'londonhong kong', 'reuters', 'hong kong', 'asian', 'thursday', 'u federal reserve', 'august', 'reuters', 'asian', 'london', 'reuters', 'wednesday', 'microsoft', 'asia', 'mellon university', 'weekend', 'early sunday', 'sixth', 'first', 'friday', 'sixth', 'first', 'friday', 'huang mandel', 'thursday', 'new york stock exchange', 'nyse', 'july', 'new york city', 'weekly', 'alex masmej', 'san francisco', 'california']

# %% [markdown]
# ---
